# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("/Users/james.fung/Desktop/test_scripts/debt_relief/listings.csv")

# %%
data.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2595                             Skylit Midtown Castle     2845
# 1  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 2  3831                   Cozy Entire Floor of Brownstone     4869
# 3  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 4  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 5  5121                                   BlissArtsSpace!     7356
# 6  5178                  Large Furnished Room Near B'way      8967
# 7  5203                Cozy Clean Guest Room - Family Apt     7490
# 8  5222                                     Best Hideaway     7516
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1    Elisabeth           Manhattan              Harlem  40.80902  -73.94190
# 2  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 3        Laura           Manhattan         East Harlem  40.79851  -73.94399
# 4        Chris           Manhattan         Murray Hill  40.74767  -73.97500
# 5        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 6     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 7    MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
# 8      Marilyn           Manhattan        East Village  40.72764  -73.97949
# 9          Ben           Manhattan           Chinatown  40.71344  -73.99037
#
#          room_type  minimum_nights  calculated_host_listings_count  \
# 0  Entire home/apt               1                               2
# 1     Private room               3                               1
# 2  Entire home/apt               1                               1
# 3  Entire home/apt              10                               1
# 4  Entire home/apt               3                               1
# 5     Private room              45                               1
# 6     Private room               2                               1
# 7     Private room               2                               1
# 8  Entire home/apt              30                               1
# 9  Entire home/apt               1                               4
#
#    availability_365  number_of_reviews  reviews_per_month  price
# 0               288                 46               0.39    225
# 1               365                  0                NaN    150
# 2               212                274               4.64     89
# 3                 0                  9               0.10     80
# 4               127                 75               0.60    200
# 5                 0                 49               0.39     60
# 6               239                434               3.48     79
# 7                 0                118               0.98     79
# 8               322                 94               0.74    116
# 9                 0                161               1.33    150

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48864 entries, 0 to 48863
# Data columns (total 15 columns):
# id                                48864 non-null int64
# name                              48848 non-null object
# host_id                           48864 non-null int64
# host_name                         48846 non-null object
# neighbourhood_group               48864 non-null object
# neighbourhood                     48864 non-null object
# latitude                          48864 non-null float64
# longitude                         48864 non-null float64
# room_type                         48864 non-null object
# minimum_nights                    48864 non-null int64
# calculated_host_listings_count    48864 non-null int64
# availability_365                  48864 non-null int64
# number_of_reviews                 48864 non-null int64
# reviews_per_month                 38733 non-null float64
# price                             48864 non-null int64
# dtypes: float64(3), int64(7), object(5)
# memory usage: 5.6+ MB

# %%
#Drop some unecessary columns
data = data.drop(['id'],axis=1)

# %%
data
# Out:
#                                                     name    host_id  \
# 0                                  Skylit Midtown Castle       2845
# 1                    THE VILLAGE OF HARLEM....NEW YORK !       4632
# 2                        Cozy Entire Floor of Brownstone       4869
# 3       Entire Apt: Spacious Studio/Loft by central park       7192
# 4              Large Cozy 1 BR Apartment In Midtown East       7322
# 5                                        BlissArtsSpace!       7356
# 6                       Large Furnished Room Near B'way        8967
# 7                     Cozy Clean Guest Room - Family Apt       7490
# 8                                          Best Hideaway       7516
# 3      -73.94399  Entire home/apt              10
# 4      -73.97500  Entire home/apt               3
# 5      -73.95596     Private room              45
# 6      -73.98493     Private room               2
# 7      -73.96723     Private room               2
# 8      -73.97949  Entire home/apt              30
# 9      -73.99037  Entire home/apt               1
# 10     -73.96545  Entire home/apt               5
# 11     -73.98867     Private room               2
# 12     -73.98779     Private room               4
# 13     -74.00525  Entire home/apt              90
# 14     -73.95352  Entire home/apt               2
# 15     -73.97185  Entire home/apt               2
# 16     -73.99501     Private room               1
# 17     -73.94694  Entire home/apt               3
# 18     -73.94872  Entire home/apt               7
# 19     -73.95718  Entire home/apt               3
# 20     -73.97706     Private room               2
# 21     -73.97865     Private room               2
# 22     -73.94028  Entire home/apt               2
# 23     -73.97519     Private room               1
# 24     -73.92639     Private room               4
# 25     -73.98533  Entire home/apt              10
# 26     -73.98542  Entire home/apt              14
# 27     -73.95104     Private room               3
# 28     -73.95466     Private room               2
# 29     -73.93762     Private room               4
# ...          ...              ...             ...
# 48834  -74.00339  Entire home/apt               7
# 48835  -73.99997  Entire home/apt               2
# 48836  -73.94808     Private room               2
# 48837  -74.00893  Entire home/apt              30
# 48838  -73.99850  Entire home/apt               2
# 48839  -73.92282     Private room               1
# 48840  -73.96743  Entire home/apt               5
# 48841  -73.94626  Entire home/apt               2
# 48842  -73.99131  Entire home/apt               2
# 48843  -73.94626  Entire home/apt               2
# 48844  -73.96008  Entire home/apt               3
# 48845  -73.97282  Entire home/apt               3
# 48846  -73.94626  Entire home/apt               2
# 48847  -73.97799  Entire home/apt               1
# 48848  -73.96581  Entire home/apt               2
# 48849  -73.98576  Entire home/apt               2
# 48850  -73.95032  Entire home/apt              30
# 48851  -73.99869  Entire home/apt               1
# 48852  -73.98521  Entire home/apt               2
# 48853  -73.97374  Entire home/apt              30
# 48854  -74.00939  Entire home/apt               1
# 48855  -73.98575  Entire home/apt               2
# 48856  -73.99249     Private room               1
# 48857  -73.92283  Entire home/apt               2
# 48858  -73.88425  Entire home/apt               1
# 48859  -73.92567      Shared room               1
# 48860  -73.93774     Private room               2
# 48861  -73.98818  Entire home/apt               1
# 48862  -73.95931     Private room               1
# 48863  -73.98972  Entire home/apt               1
#
#        calculated_host_listings_count  availability_365  number_of_reviews  \
# 0                                   2               288                 46
# 1                                   1               365                  0
# 2                                   1               212                274
# 3                                   1                 0                  9
# 4                                   1               127                 75
# 5                                   1                 0                 49
# 6                                   1               239                434
# 7                                   1                 0                118
# 8                                   1               322                 94
# 9                                   4                 0                161
# 10                                  1                 1                 53
# 11                                  1                23                190
# 12                                  3               324                167
# 13                                  1                 4                 27
# 14                                  1                23                154
# 15                                  1               305                200
# 16                                  1                 5                268
# 17                                  1                22                 59
# 18                                  2               275                  0
# 19                                  1                 0                  9
# 20                                  4               117                131
# 21                                  4               290                 73
# 22                                  2               251                 92
# 23                                  2                89                 20
# 24                                  1                 0                  0
# 25                                  1               104                 58
# 26                                  1                42                 29
# 27                                  3               341                244
# 28                                  1               252                 92
# 29                                  3               309                201
# ...                               ...               ...                ...
# 48834                               1               309                  0
# 48835                               1                81                  0
# 48836                               1                16                  0
# 48837                               1                44                  0
# 48838                               1                80                  0
# 48839                               1                66                  0
# 48840                               1               342                  0
# 48841                               3               326                  0
# 48842                               1               262                  0
# 48843                               3               337                  0
# 48844                               1                18                  0
# 48845                               2                83                  0
# 48846                               3               332                  0
# 48847                               3               145                  0
# 48848                               1                 0                  0
# 48849                               1                45                  0
# 48850                              32               339                  0
# 48851                               1                66                  0
# 48852                               1                52                  0
# 48853                              10               340                  0
# 48854                               1                51                  0
# 48855                               1                22                  0
# 48856                               2               171                  0
# 48857                               1               358                  0
# 48858                               1               354                  0
# 48859                               1                53                  0
# 48860                               1                53                  0
# 48861                               1               105                  0
# 48862                               1                14                  0
# 48863                               1                74                  0
#
#        reviews_per_month  price
# 0                   0.39    225
# 1                    NaN    150
# 2                   4.64     89
# 3                   0.10     80
# 4                   0.60    200
# 5                   0.39     60
# 6                   3.48     79
# 7                   0.98     79
# 8                   0.74    116
# 9                   1.33    150
# 10                  0.42    135
# 11                  1.50     85
# 12                  1.33     89
# 13                  0.22    120
# 14                  1.24    140
# 15                  1.72    215
# 16                  2.17    140
# 17                  4.59     99
# 18                   NaN    190
# 19                  0.07    299
# 20                  1.09    115
# 21                  0.63    110
# 22                  0.76    120
# 23                  1.35     60
# 24                   NaN     80
# 25                  0.48    150
# 26                  0.24    180
# 27                  2.04     50
# 28                  1.46     52
# 29                  1.67     55
# ...                  ...    ...
# 48834                NaN    499
# 48835                NaN    180
# 48836                NaN    105
# 48837                NaN    150
# 48838                NaN    180
# 48839                NaN     65
# 48840                NaN    315
# 48841                NaN   1295
# 48842                NaN    250
# 48843                NaN    895
# 48844                NaN    150
# 48845                NaN    280
# 48846                NaN    395
# 48847                NaN    350
# 48848                NaN    100
# 48849                NaN    180
# 48850                NaN    190
# 48851                NaN    236
# 48852                NaN    180
# 48853                NaN    300
# 48854                NaN    709
# 48855                NaN    180
# 48856                NaN    135
# 48857                NaN    300
# 48858                NaN    130
# 48859                NaN     65
# 48860                NaN     60
# 48861                NaN    239
# 48862                NaN     75
# 48863                NaN    239
#
# [48864 rows x 14 columns]

# %% [markdown]
# Problem:
#
# Given only this data, you want to create a model to predict how much you can charge for new listings while keeping vacancy down.
# Please put together a brief analysis of the dataset and show how you would go about creating a model to predict a listing price, while taking market demand into account.

# %%
X = data.drop(['price'],axis=1)
y = data.price

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ### Preliminary EDA

# %%
#Zip up X_train and y_train for some EDA.

train = pd.concat([X_train, y_train],axis=1)

# %%
#Any missing values?
train.isnull().sum()
# Out:
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# minimum_nights                    0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews                 0
# reviews_per_month                 0
# price                             0
# dtype: int64

# %% [markdown]
# Name and host_name seem reasonable to have missing information. Reviews per month could be missing if there are no reviews per month?

# %%
train[train.reviews_per_month.isna() == True].number_of_reviews.value_counts()
# Out:
# 0    7035
# Name: number_of_reviews, dtype: int64

# %%
#Fill in the NA values with 0.

train.reviews_per_month = train.reviews_per_month.fillna(value=0)
train.name = train.name.fillna(value='None')
train.host_name = train.name.fillna(value='None')

# %%
#What is the distribution of Y?

sb.distplot(train.price)

# %% [markdown]
# This is extremely right skewed, and also seems to contain some extreme outliers.

# %%
train.price.describe()
# Out:
# count    34204.000000
# mean       152.283768
# std        238.925579
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
#What is the correlation between then umerical values and price?
num=train.select_dtypes(exclude='object')
num.corr().price.to_frame().sort_values(by='price', ascending=False)
# Out:
#                                    price
# price                           1.000000
# availability_365                0.085360
# calculated_host_listings_count  0.059375
# minimum_nights                  0.050607
# latitude                        0.035190
# host_id                         0.003106
# number_of_reviews              -0.047305
# reviews_per_month              -0.055012
# longitude                      -0.150522

# %% [markdown]
# There are extremely weak correlations between many of the numerical values and the final price.

# %%
#What is the relationship between the categorical features and price?
train[['room_type','price']].groupby('room_type').median().sort_values(by='price', ascending=False)
# Out:
#                  price
# room_type
# Entire home/apt    160
# Private room        70
# Shared room         45

# %% [markdown]
# Not surprising that entire home/apt's are higher priced.

# %%
train[['neighbourhood_group','price']].groupby('neighbourhood_group').median().sort_values(by='price', ascending=False)
# Out:
#                      price
# neighbourhood_group
# Manhattan              150
# Brooklyn                91
# Staten Island           75
# Queens                  71
# Bronx                   65

# %% [markdown]
# Not surprising that Manhattan is also the most expensive. A bit surprised that Staten Island is above Queens.

# %%
train.neighbourhood.value_counts().to_frame()
# Out:
#                             neighbourhood
# Williamsburg                         2700
# Bedford-Stuyvesant                   2685
# Harlem                               1839
# Bushwick                             1673
# Hell's Kitchen                       1380
# Upper West Side                      1344
# East Village                         1302
# Upper East Side                      1218
# Crown Heights                        1107
# Midtown                              1033
# Chelsea                               793
# East Harlem                           773
# Greenpoint                            763
# Washington Heights                    652
# Astoria                               624
# Lower East Side                       605
# West Village                          538
# Financial District                    518
# Flatbush                              435
# Clinton Hill                          408
# Prospect-Lefferts Gardens             378
# Long Island City                      367
# Park Slope                            351
# Fort Greene                           350
# Murray Hill                           341
# Kips Bay                              331
# East Flatbush                         323
# Ridgewood                             320
# Flushing                              299
# Greenwich Village                     281
# ...                                   ...
# Dongan Hills                            4
# Breezy Point                            3
# Oakwood                                 3
# North Riverdale                         3
# Huguenot                                3
# Arden Heights                           3
# Rosebank                                3
# New Brighton                            3
# Graniteville                            2
# Spuyten Duyvil                          2
# New Dorp Beach                          2
# Castle Hill                             2
# Bull's Head                             2
# Bay Terrace, Staten Island              2
# Midland Beach                           2
# Neponsit                                2
# Holliswood                              2
# Eltingville                             2
# Todt Hill                               1
# Lighthouse Hill                         1
# Silver Lake                             1
# Willowbrook                             1
# Woodrow                                 1
# Richmondtown                            1
# Country Club                            1
# Westerleigh                             1
# Prince's Bay                            1
# Fort Wadsworth                          1
# Co-op City                              1
# New Dorp                                1
#
# [219 rows x 1 columns]

# %% [markdown]
# There are some extremely rare neighborhoods - these will probably be unimformative, won't help with our predictions, and increase the dimensionality of our data. Let's reclassify rare neighborhoods into 'other.'

# %%
X_train.neighbourhood.where(
    X_train.neighbourhood.apply(
        lambda x: x.value_counts()/len(X_train) <= cutoff, 'Other'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-b3a28340e6bf> in <module>
#       1 X_train.neighbourhood.where(
#       2     X_train.neighbourhood.apply(
# ----> 3         lambda x: x.value_counts()/len(X_train) <= cutoff, 'Other'))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-54-b3a28340e6bf> in <lambda>(x)
#       1 X_train.neighbourhood.where(
#       2     X_train.neighbourhood.apply(
# ----> 3         lambda x: x.value_counts()/len(X_train) <= cutoff, 'Other'))
#
# AttributeError: 'str' object has no attribute 'value_counts'

# %%
data.where(data.apply(lambda x: x.map(x.value_counts()))>=2, "other")
